# %%
body = {
  "messages": [
    {"role": "user", "content": "你好"},
    {"role": "assistant", "content": "哈囉"},
    {"role": "user", "content": "你好嗎???"}
  ]
}
massage1 = body.get("messages",[])
body.get("messages",[])[2].get("content","")
# Out:
# '你好嗎???'

# %%
last_massage = massage1[-1]
massage_content = last_massage.get("content","")
length = len(massage_content)
last_massage[""] += f"\n\n*(系統分析：這則訊息的長度是 {length} 個字)*"
massage_content
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 4
#       2 massage_content = last_massage.get("content","")
#       3 length = len(massage_content)
# ----> 4 massage_content[""] += f"\n\n*(系統分析：這則訊息的長度是 {length} 個字)*"
#       5 massage_content
#
# TypeError: string indices must be integers, not 'str'
